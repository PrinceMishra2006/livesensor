# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\mishr\onedrive\desktop\sensorlive\venv\lib\site-packages (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo 
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://prince123:1234@cluster0.fwoo9or.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db = client['liveclass']

# %%
collection = db['mongoclass']

# %%
data = {
    "name":"prince mishra",
    "age":19,
    "email":"mishrajii1476@gmail.com"
}

# %%
collection.insert_one(data)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('686aa80827535ab19d8f2d78'), 'name': 'prince mishra', 'age': 19, 'email': 'mishrajii1476@gmail.com'}
